# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
uploaded = files.upload()
weather = pd.read_csv("weather.csv", index_col="DATE")
# Out:
#      <input type="file" id="files-601cded7-9b74-4ef0-a61d-1dca1702d6a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-601cded7-9b74-4ef0-a61d-1dca1702d6a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH   ACSH  \
# DATE
# 1970-01-01  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US  60.0   80.0
# 1970-01-02  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US  10.0    0.0
# 1970-01-03  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   0.0    0.0
# 1970-01-04  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US  80.0  100.0
# 1970-01-05  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US  70.0   90.0
# ...                 ...                                   ...   ...    ...
# 2025-06-11  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   NaN    NaN
# 2025-06-12  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   NaN    NaN
# 2025-06-13  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   NaN    NaN
# 2025-06-14  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   NaN    NaN
# 2025-06-15  USW00023042  LUBBOCK INTERNATIONAL AIRPORT, TX US   NaN    NaN
#
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.537201
# ACSH       0.537201
# AWND       0.253024
# FMTM       0.498494
# PGTM       0.332362
# PRCP       0.000000
# PSUN       0.800148
# SNOW       0.000296
# SNWD       0.000197
# TAVG       0.647692
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.543816
# WDF1       0.537201
# WDF2       0.462997
# WDF5       0.463293
# WDFG       0.586324
# WESD       0.706986
# WSF1       0.537201
# WSF2       0.462997
# WSF5       0.463293
# WSFG       0.586226
# WT01       0.786917
# WT02       0.951617
# WT03       0.868576
# WT04       0.991212
# WT05       0.980795
# WT06       0.982720
# WT07       0.968699
# WT08       0.918983
# WT09       0.993779
# WT10       0.999457
# WT11       0.997285
# WT13       0.934683
# WT14       0.974130
# WT15       0.994767
# WT16       0.801728
# WT17       0.996988
# WT18       0.966231
# WT19       0.999704
# WT21       0.999753
# WT22       0.996544
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip        0
# snow          6
# snow_depth    4
# temp_max      0
# temp_min      0
# dtype: int64

# %%
core_weather["snow"].value_counts()
# Out:
# snow
# 0.0     19881
# 0.1        50
# 0.3        37
# 0.4        35
# 0.2        34
# 0.8        18
# 0.6        16
# 0.5        16
# 1.0        14
# 1.3        11
# 0.7        10
# 1.2         9
# 1.4         8
# 1.8         7
# 1.5         7
# 1.1         7
# 1.6         6
# 3.5         5
# 0.9         5
# 2.0         4
# 1.7         4
# 2.1         4
# 2.8         4
# 2.5         4
# 2.9         4
# 2.2         4
# 1.9         4
# 3.4         3
# 3.0         3
# 3.7         3
# 4.2         2
# 7.6         2
# 7.0         2
# 3.1         2
# 2.6         2
# 4.0         2
# 6.6         1
# 3.8         1
# 10.6        1
# 2.4         1
# 8.1         1
# 3.2         1
# 10.3        1
# 11.4        1
# 5.2         1
# 4.4         1
# 5.5         1
# 3.3         1
# 8.3         1
# 6.2         1
# 2.7         1
# 4.6         1
# 11.0        1
# 10.0        1
# 7.2         1
# 3.6         1
# Name: count, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 0.0     19954
# 1.0       104
# 2.0        73
# 3.0        38
# 4.0        21
# 1.2        17
# 5.0         8
# 7.0         8
# 9.0         4
# 3.1         4
# 3.9         4
# 6.0         4
# 11.0        3
# 8.0         2
# 10.0        1
# 15.0        1
# 17.0        1
# 12.0        1
# 16.0        1
# 9.8         1
# 5.1         1
# Name: count, dtype: int64

# %%
del core_weather["snow"]

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []

# %%
core_weather.loc["2013-12-15",:]
# Out:
# precip       0.0
# temp_max    60.0
# temp_min    21.0
# Name: 2013-12-15, dtype: float64

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# precip
# 0.00    0.827351
# 0.01    0.019896
# 0.02    0.013725
# 0.03    0.009726
# 0.04    0.007899
#           ...
# 1.42    0.000049
# 1.49    0.000049
# 1.52    0.000049
# 1.95    0.000049
# 2.70    0.000049
# Name: count, Length: 217, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []

# %%
core_weather = core_weather.ffill()

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max      int64
# temp_min      int64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2025-06-06', '2025-06-07', '2025-06-08', '2025-06-09', '2025-06-10',
#        '2025-06-11', '2025-06-12', '2025-06-13', '2025-06-14', '2025-06-15'],
#       dtype='object', name='DATE', length=20255)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2025-06-06', '2025-06-07', '2025-06-08', '2025-06-09',
#                '2025-06-10', '2025-06-11', '2025-06-12', '2025-06-13',
#                '2025-06-14', '2025-06-15'],
#               dtype='datetime64[ns]', name='DATE', length=20255, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#        ...
#        2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025],
#       dtype='int32', name='DATE', length=20255)

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025    166
# Name: count, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01     0.0        39        12    39.0
# 1970-01-02     0.0        39        15    41.0
# 1970-01-03     0.0        41        18    47.0
# 1970-01-04     0.0        47        14    35.0
# 1970-01-05     0.0        35        13    33.0
# ...            ...       ...       ...     ...
# 2025-06-11     0.0        84        68    90.0
# 2025-06-12     0.0        90        64    96.0
# 2025-06-13     0.0        96        70    97.0
# 2025-06-14     0.0        97        68    88.0
# 2025-06-15     0.0        88        74     NaN
#
# [20255 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01    0.00        39        12    39.0
# 1970-01-02    0.00        39        15    41.0
# 1970-01-03    0.00        41        18    47.0
# 1970-01-04    0.00        47        14    35.0
# 1970-01-05    0.00        35        13    33.0
# ...            ...       ...       ...     ...
# 2025-06-10    0.12        83        64    84.0
# 2025-06-11    0.00        84        68    90.0
# 2025-06-12    0.00        90        64    96.0
# 2025-06-13    0.00        96        70    97.0
# 2025-06-14    0.00        97        68    88.0
#
# [20254 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]
test = core_weather.loc["2021-01-01":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01    0.00        39        12    39.0
# 1970-01-02    0.00        39        15    41.0
# 1970-01-03    0.00        41        18    47.0
# 1970-01-04    0.00        47        14    35.0
# 1970-01-05    0.00        35        13    33.0
# ...            ...       ...       ...     ...
# 2020-12-27    0.00        66        38    51.0
# 2020-12-28    0.00        51        36    69.0
# 2020-12-29    0.00        69        41    48.0
# 2020-12-30    0.04        48        31    39.0
# 2020-12-31    0.00        39        23    48.0
#
# [18628 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2021-01-01    0.00        48        25    60.0
# 2021-01-02    0.00        60        24    61.0
# 2021-01-03    0.00        61        29    63.0
# 2021-01-04    0.00        63        33    61.0
# 2021-01-05    0.00        61        28    54.0
# ...            ...       ...       ...     ...
# 2025-06-10    0.12        83        64    84.0
# 2025-06-11    0.00        84        68    90.0
# 2025-06-12    0.00        90        64    96.0
# 2025-06-13    0.00        96        70    97.0
# 2025-06-14    0.00        97        68    88.0
#
# [1626 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 78.3186544037959

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    60.0    52.055528
# 2021-01-02    61.0    59.243658
# 2021-01-03    63.0    61.224327
# 2021-01-04    61.0    63.554855
# 2021-01-05    54.0    60.952525
# ...            ...          ...
# 2025-06-10    84.0    84.049514
# 2025-06-11    90.0    86.122791
# 2025-06-12    96.0    88.765550
# 2025-06-13    97.0    94.126326
# 2025-06-14    88.0    94.204384
#
# [1626 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-3.03674676,  0.62166097,  0.27180159])

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
core_weather = core_weather.replace([np.inf, -np.inf], np.nan).dropna()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)

    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

error, combined = create_predictions(predictors, core_weather, reg)
error
# Out:
# 76.45082979148903

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather.groupby(core_weather.index.month)["temp_max"].transform(lambda x: x.expanding(1).mean())
core_weather["day_of_year_avg"] = core_weather.groupby(core_weather.index.dayofyear)["temp_max"].transform(lambda x: x.expanding(1).mean())

# %%
error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg)
error
# Out:
# 70.51389552501716

# %%
reg.coef_
# Out:
# array([-4.00841215,  0.56583614, -0.04125732, -0.84682888, -0.09432566,
#         0.31352464,  0.17471068])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.030316
# temp_max           0.851249
# temp_min           0.799685
# target             1.000000
# month_max          0.777189
# month_day_max     -0.413314
# max_min           -0.259735
# monthly_avg        0.792115
# day_of_year_avg    0.804929
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2024-01-13    18.0    58.562020  40.562020
# 2022-02-22    26.0    59.263949  33.263949
# 2025-02-18    23.0    54.906905  31.906905
# 2022-12-22    18.0    48.712507  30.712507
# 2022-02-02    17.0    46.292531  29.292531
# 2025-02-04    88.0    60.248652  27.751348
# 2024-01-18    37.0    64.037847  27.037847
# 2023-05-12    63.0    89.167324  26.167324
# 2023-02-15    39.0    64.689379  25.689379
# 2022-11-17    34.0    59.520211  25.520211

# %%
combined[["actual", "predictions"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.scatter(combined['actual'], combined['predictions'], alpha=0.5)
plt.plot([combined['actual'].min(), combined['actual'].max()],
         [combined['actual'].min(), combined['actual'].max()], 'r--')
plt.xlabel('Actual Temperature')
plt.ylabel('Predicted Temperature')
plt.title('Actual vs Predicted Scatter')
plt.show()

# %%
combined['residual'] = combined['actual'] - combined['predictions']
combined['residual'].plot(figsize=(12,4), title="Prediction Residuals (Error Analysis)")
# Out:
# <Axes: title={'center': 'Prediction Residuals (Error Analysis)'}, xlabel='DATE'>
